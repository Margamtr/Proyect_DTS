# %% [markdown]
# #Revisión general de los datos.

# %%
#Tratamiento y exportación de datos
#importamos librerias
import pandas as pd    # Librería para tablas y tratamiento de datos.
#Para una visualización completa de todas las columnas:
pd.set_option('display.max_columns', None)
#Accedemos a las funciones en soporte_dts de la carpeta src
from src import soporte_dts as sdts

# %% [markdown]
# # 1-EXTRACCION DATOS

# %% [markdown]
# Extracción de datos e información esencial

# %%
#Extraemos los datos:
df_clientes=sdts.leer_datos('clientes.csv')
df_productos=sdts.leer_datos('productos.csv')
df_ventas=sdts.leer_datos('ventas.csv')

# %%
sdts.explorar_datos(df_clientes)
# Out:
# Muestra de DataFrame
#     id_cliente  nombre   apellido             ciudad
# 273      C0274   Laura  Fernández  Santander, España
# 18       C0019   María      López   Valencia, España
# 10       C0011   Lucía  Fernández      Lyon, Francia
# 61       C0062  Carmen  Hernández  Coímbra, Portugal
# 292      C0293   Julia      López    Sevilla, España
# INFORMACION:
#
# Columnas: 4
# Filas: 300
#
# Columnas, tipo de datos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  300 non-null    object
#  1   nombre      300 non-null    object
#  2   apellido    300 non-null    object
#  3   ciudad      300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB
# None
# Valores duplicados:
# NO HAY VALORES DUPLICADOS

# %%
sdts.explorar_datos(df_productos)
# Out:
# Muestra de DataFrame
#     id_producto   precio          categoria  \
# 62        P0063  71.80 €  Sports & Outdoors
# 80        P0081  59.58 €     Home & Kitchen
# 126       P0127  69.00 €           Clothing
# 455       P0456  43.80 €  Sports & Outdoors
# 217       P0218  64.55 €           Clothing
#
#                                            descripcion
# 62   Ce9COxf893DO5o8weerGurKp9ZWDZUh2OkkqFnLpYN5MTH...
# 80   uewqC0BeZjYQ496sDsnwDCgtzeGphJR7vkC1CkBJBkZ4WK...
# 126  mIsfNeNmgYBUzqvf7GSK3L9kd7Ikzgo3Ozu0ivb3Q9ZHC6...
# 455  Y6zgdgNy54eZaDqcg5n089wksjTGcnJV9ExMRHi7uPBNoI...
# 217  bL6H8JNyZbd0Ag34yH4ZxcLul5ZKs7WHOwlq6ilIDN8nXp...
# INFORMACION:
#
# Columnas: 4
# Filas: 600
#
# Columnas, tipo de datos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_producto  600 non-null    object
# ...

# %%
sdts.explorar_datos(df_ventas)
# Out:
# Muestra de DataFrame
#       id_venta id_producto  cantidad       fecha id_cliente
# 53285  V005458       P0043         3  2023-01-09      C0116
# 73038  V005568       P0141         6  2024-02-16      C0275
# 64115  V005828       P0206         6  2022-03-12      C0067
# 41586  V001907       P0515         5  2021-04-10      C0045
# 14365  V007368       P0428         1  2023-11-13      C0291
# INFORMACION:
#
# Columnas: 5
# Filas: 80000
#
# Columnas, tipo de datos:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     80000 non-null  object
#  1   id_producto  80000 non-null  object
#  2   cantidad     80000 non-null  int64
#  3   fecha        80000 non-null  object
#  4   id_cliente   80000 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.1+ MB
# None
# Valores duplicados:
# ...

# %%
#Revisamos los valores unicos:
df_ventas.value_counts()
# Out:
# id_venta  id_producto  cantidad  fecha       id_cliente
# V001790   P0459        10        2020-09-08  C0244         2
# V002315   P0412        8         2023-07-31  C0113         2
# V007226   P0269        2         2021-10-21  C0215         2
# V004086   P0543        2         2022-09-17  C0131         2
# V001353   P0108        2         2021-04-09  C0038         2
#                                                           ..
# V002655   P0332        8         2022-07-15  C0093         1
#           P0172        4         2022-07-15  C0093         1
#           P0122        4         2022-07-15  C0093         1
#           P0103        4         2022-07-15  C0093         1
# V008000   P0549        1         2021-01-11  C0156         1
# Name: count, Length: 79920, dtype: int64

# %% [markdown]
# # UNIÓN TABLAS
# Pasaremos todos los datos a un solo dataframe:

# %%
merge1_dfs=df_ventas.merge(df_clientes, on ="id_cliente")

# %%
merge1_dfs.head()
# Out:
#   id_venta id_producto  cantidad       fecha id_cliente nombre   apellido  \
# 0  V004849       P0173         4  2024-05-16      C0203  Lucía   González
# 1  V003181       P0165         9  2022-09-12      C0004  Marta      López
# 2  V000311       P0194        10  2020-12-02      C0156  Sofía    Sánchez
# 3  V002787       P0167         1  2023-07-22      C0058  Clara  Hernández
# 4  V002726       P0417        10  2022-04-10      C0099  Elena     García
#
#               ciudad
# 0      Niza, Francia
# 1   Valencia, España
# 2  Santander, España
# 3  Barcelona, España
# 4   Lisboa, Portugal

# %%
merge2_dfs=merge1_dfs.merge(df_productos, on="id_producto")

# %%
merge2_dfs.head()
# Out:
#   id_venta id_producto  cantidad       fecha id_cliente nombre   apellido  \
# 0  V004849       P0173         4  2024-05-16      C0203  Lucía   González
# 1  V003181       P0165         9  2022-09-12      C0004  Marta      López
# 2  V000311       P0194        10  2020-12-02      C0156  Sofía    Sánchez
# 3  V002787       P0167         1  2023-07-22      C0058  Clara  Hernández
# 4  V002726       P0417        10  2022-04-10      C0099  Elena     García
#
#               ciudad   precio          categoria  \
# 0      Niza, Francia  58.91 €              Books
# 1   Valencia, España  93.20 €              Books
# 2  Santander, España  43.38 €           Clothing
# 3  Barcelona, España  88.17 €  Sports & Outdoors
# 4   Lisboa, Portugal  60.69 €              Books
#
#                                          descripcion
# 0  UASpWkt14nzeB6fkBDwO42wQiCijnSTcizwW1eB1yy0Rmy...
# 1  Wk3wS8V6kUhy0nWnknaaSiS3oQJkfAf8pOK0GAbRqMwQ3L...
# 2  eOnRpP74GAXrDk8UMb6QgmSJscSgpT9B5B9C1PA1TB9Xc5...
# ...

# %%
merge2_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     80000 non-null  object
#  1   id_producto  80000 non-null  object
#  2   cantidad     80000 non-null  int64
#  3   fecha        80000 non-null  object
#  4   id_cliente   80000 non-null  object
#  5   nombre       80000 non-null  object
#  6   apellido     80000 non-null  object
#  7   ciudad       80000 non-null  object
#  8   precio       80000 non-null  object
#  9   categoria    80000 non-null  object
#  10  descripcion  80000 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 6.7+ MB

# %% [markdown]
# # NORMALIZACIÓN DATOS Y LIMPIEZA

# %%
#Vamos a separarcolumnas siguiendo el proceso de normalizacion de una tabla:
#Separaremos la columna ciudad en dos: ciudad y país.
merge2_dfs[['ciudad','pais']]=merge2_dfs.ciudad.str.split(', ', expand=True)
merge2_dfs.head(1)
# Out:
#   id_venta id_producto  cantidad       fecha id_cliente nombre  apellido  \
# 0  V004849       P0173         4  2024-05-16      C0203  Lucía  González
#
#   ciudad   precio categoria  \
# 0   Niza  58.91 €     Books
#
#                                          descripcion     pais
# 0  UASpWkt14nzeB6fkBDwO42wQiCijnSTcizwW1eB1yy0Rmy...  Francia

# %%
#separaremos '€' de la columna precios y ccambiaremos su tipo de valor a float.
merge2_dfs.precio=merge2_dfs.precio.str.replace('€','')
merge2_dfs.head(1)
# Out:
#   id_venta id_producto  cantidad       fecha id_cliente nombre  apellido  \
# 0  V004849       P0173         4  2024-05-16      C0203  Lucía  González
#
#   ciudad  precio categoria                                        descripcion  \
# 0   Niza  58.91      Books  UASpWkt14nzeB6fkBDwO42wQiCijnSTcizwW1eB1yy0Rmy...
#
#       pais
# 0  Francia

# %%
#Cambiamos el tipo de valor al precio de object a float
merge2_dfs.precio=merge2_dfs.precio.astype(float)

# %%
merge2_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     80000 non-null  object
#  1   id_producto  80000 non-null  object
#  2   cantidad     80000 non-null  int64
#  3   fecha        80000 non-null  object
#  4   id_cliente   80000 non-null  object
#  5   nombre       80000 non-null  object
#  6   apellido     80000 non-null  object
#  7   ciudad       80000 non-null  object
#  8   precio       80000 non-null  float64
#  9   categoria    80000 non-null  object
#  10  descripcion  80000 non-null  object
#  11  pais         80000 non-null  object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 7.3+ MB

# %%
#Procedemos a guardar el df _limpio:
merge2_dfs.to_csv('clientes_productos_ventas.csv')

# %% [markdown]
# TRATAMOS LAS FILAS DUPLICADAS

# %%
sdts.info_duplicados(merge2_dfs)
# Out:
# El DataFrame presenta 80 filas duplicadas
# El porcentaje de duplicados es de un 0.1 %.
# (      id_venta id_producto  cantidad       fecha id_cliente  nombre  \
#  6694   V004648       P0434         5  2021-06-28      C0263   Lucía
#  8773   V001670       P0483         4  2020-07-31      C0017   Clara
#  10797  V004342       P0336         3  2020-05-27      C0267   Marta
#  10967  V004143       P0373         4  2021-11-18      C0300  Carmen
#  12262  V003463       P0181         6  2021-06-16      C0070   Clara
#  ...        ...         ...       ...         ...        ...     ...
#  78821  V004712       P0307         7  2023-09-29      C0076   Lucía
#  79104  V004713       P0559        10  2020-03-16      C0046   Sofía
#  79439  V006831       P0263         2  2022-10-30      C0168   Laura
#  79734  V003482       P0388         7  2023-07-22      C0099   Elena
#  79962  V000454       P0193         9  2023-11-16      C0032   Laura
#
# ...

# %%
#Eliminamos las filas repetidas ya que suponen un 0,1% de los datos y creamos un df_nuevo:
df_limpio=merge2_dfs.drop_duplicates()

# %%
df_limpio.duplicated().sum()
# Out:
# 0

# %%
#Procedemos a guardar el df _limpio:
df_limpio.to_csv('clientes_productos_ventas_limpio.csv',index=False)

# %% [markdown]
# # EDA

# %% [markdown]
# Sacamos los valores unicos para una última revision y para la separación por categorias de cada columna:

# %%
sdts.valores_unicos_frecuencias(df_limpio)
# Out:
# Para la columna id_venta los valores únicos son:
#
# id_venta
# V005860    23
# V004944    23
# V002430    23
# V000395    22
# V005828    21
#            ..
# V000561     2
# V000130     1
# V001199     1
# V002861     1
# V000696     1
# Name: count, Length: 8000, dtype: int64
#
# Para la columna id_producto los valores únicos son:
#
# id_producto
# P0057    209
# P0269    208
# P0193    201
# P0026    199
# P0068    197
#         ...
# P0315    135
# P0249    134
# P0147    132
# P0445    131
# P0532    131
# Name: count, Length: 480, dtype: int64
#
# Para la columna cantidad los valores únicos son:
#
# cantidad
# 9     8134
# 6     8101
# 4     8072
# 10    8031
# 1     7998
# 2     7967
# 3     7951
# 7     7927
# 5     7900
# 8     7839
# Name: count, dtype: int64
#
# Para la columna fecha los valores únicos son:
#
# fecha
# 2021-12-22    149
# 2022-12-04    140
# 2020-11-30    130
# 2023-09-20    126
# 2020-01-19    124
#              ...
# 2024-04-01      6
# ...

# %% [markdown]
# EXPLORAMOS LOS DATOS POR TIPO DE VARIABLE

# %%
sdts.estudio_variables(df_limpio,'categoricas')
# Out:
# Las variables de tipo categoricas son:
# ['id_venta', 'id_producto', 'fecha', 'id_cliente', 'nombre', 'apellido', 'ciudad', 'categoria', 'descripcion', 'pais']
#
# Las principales estadísticas son:
#              count unique                                                top  \
# id_venta     79920   8000                                            V005860
# id_producto  79920    480                                              P0057
# fecha        79920   1638                                         2021-12-22
# id_cliente   79920    210                                              C0092
# nombre       79920     10                                              María
# apellido     79920     10                                          Rodríguez
# ciudad       79920     20                                            Sevilla
# categoria    79920      5                                           Clothing
# descripcion  79920    480  dcviGSuHA8rW4q9Yp1MJSSY3LJIw5B0XYyFD7GzlLIQIGG...
# ...

# %%
sdts.estudio_variables(df_limpio,'numericas')
# Out:
# Las variables de tipo numericas son:
# ['cantidad', 'precio']
#
# Las principales estadísticas son:
#             count       mean        std   min    25%    50%    75%    max
# cantidad  79920.0   5.504204   2.874844  1.00   3.00   6.00   8.00  10.00
# precio    79920.0  48.600795  27.539365  1.21  25.54  47.82  72.71  99.72
# (      id_venta id_producto       fecha id_cliente nombre   apellido  \
#  0      V004849       P0173  2024-05-16      C0203  Lucía   González
#  1      V003181       P0165  2022-09-12      C0004  Marta      López
#  2      V000311       P0194  2020-12-02      C0156  Sofía    Sánchez
#  3      V002787       P0167  2023-07-22      C0058  Clara  Hernández
#  4      V002726       P0417  2022-04-10      C0099  Elena     García
#  ...        ...         ...         ...        ...    ...        ...
#  79995  V005600       P0264  2023-02-26      C0167  Laura  Fernández
#  79996  V003626       P0564  2024-01-20      C0143  Marta     García
# ...

# %%
#Categorizamos la columna de precio. 
print(f'El precio minimo es: {df_numericas.precio.min()}')
print (f'El precio máximo es: {df_numericas.precio.max()}')
# Out:
# El precio minimo es: 1.21
# El precio máximo es: 99.72

# %%
# Los vamos a dividir en 4 categorias:
def categorizacion(precio):
    '''Categorizamos los precios en cuatro rangos.
    Args: Precio
    return: la categoria a la que pertenece
    '''
    if 1<= precio<=25:
        return 'Muy barato'
    elif 25< precio<=50:
        return 'Barato'
    elif 50< precio<=75:
        return 'Caro'
    else:
        return 'Muy caro'

# %%
 #Probamos la funcion:
print(categorizacion(2.00))
# Out:
# Muy barato

# %%
df_limpio['cat_precio']=df_limpio.precio.apply(categorizacion)
df_limpio.sample(5)
# Out:
# C:\Users\marg_\AppData\Local\Temp\ipykernel_24852\265243607.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpio['cat_precio']=df_limpio.precio.apply(categorizacion)
#       id_venta id_producto  cantidad       fecha id_cliente nombre  apellido  \
# 19030  V000810       P0525         1  2022-09-20      C0090  Marta     Gómez
# 26977  V005919       P0342         7  2021-05-27      C0132  Lucía  Martínez
# 34021  V006138       P0514         4  2022-11-18      C0132  Lucía  Martínez
# 9714   V006943       P0157         4  2023-08-23      C0099  Elena    García
# 11170  V000865       P0001         5  2022-08-19      C0212  Sofía  Martínez
#
#         ciudad  precio          categoria  \
# 19030  Sevilla   73.64              Books
# ...

# %%
df_limpio[['id_producto','precio', 'categoria','cat_precio']].sample(5)
# Out:
#       id_producto  precio       categoria  cat_precio
# 9124        P0505    9.50  Home & Kitchen  Muy barato
# 12538       P0544   80.22           Books    Muy caro
# 53906       P0171   25.81  Home & Kitchen      Barato
# 6469        P0541   25.29           Books      Barato
# 60702       P0291   25.18        Clothing      Barato

# %% [markdown]
# Limpios los datos, procedemos a crear las visualizaciones para responder las siguientes preguntas:
# -Comportamiento de Clientes: entender la antigüedad de los clientes, cuáles son los que compran más y con más frecuencia, etc.
# -Identificación de Tendencias: entender cómo han cambiado los hábitos de compra a lo largo del tiempo, como por ejemplo, si ahora se compran unas categorías que antes no o viceversa, qué días de la semana son los que más ventas acumulan, etc.
# -Optimización de Inventario: entender cuáles son las categorías más populares, los productos que ya no se venden, etc.

# %% [markdown]
# # VISUALIZACION

# %% [markdown]
# -CATEGORIAS
# * Cuéles son las categorías más populares?
# *

# %%
# Cuéles son las categorías más populares?
#! Podríamos indicar la categoría más popular indicando la categoría más frecuente.
df_categoricas.describe().T
# Out:
#              count unique                                                top  \
# id_venta     79920   8000                                            V005860
# id_producto  79920    480                                              P0057
# fecha        79920   1638                                         2021-12-22
# id_cliente   79920    210                                              C0092
# nombre       79920     10                                              María
# apellido     79920     10                                          Rodríguez
# ciudad       79920     20                                            Sevilla
# categoria    79920      5                                           Clothing
# descripcion  79920    480  dcviGSuHA8rW4q9Yp1MJSSY3LJIw5B0XYyFD7GzlLIQIGG...
# pais         79920      3                                             España
#
#               freq
# id_venta        23
# id_producto    209
# fecha          149
# id_cliente     552
# nombre       11362
# ...

# %% [markdown]
# Podemos observar que la categoría más frecuente es "Clothing". Sin embargo,tambien depende de la cantidad de cada categoria. Usaremos un histograma para todas las categorías:

# %%
df_categoricas.columns
# Out:
# Index(['id_venta', 'id_producto', 'fecha', 'id_cliente', 'nombre', 'apellido',
#        'ciudad', 'categoria', 'descripcion', 'pais'],
#       dtype='object')

# %%
print(f"Número de categorias en el df = {len(df_categoricas.categoria.unique())}")
# Out:
# Número de categorias en el df = 5

# %%
#Usaremos un diagrama pieplot para ver los productos más populares en general:
num_catego=len(df_categoricas.categoria.unique())
#Elegimos los colores de la documentacion libreria matplotlib
colores=['blueviolet', 'indigo','slateblue','violet','thistle']
#Manejo de errores
print('El numero de colores no coincide con el numero de categorias') if len(colores) > num_catego or len(colores)< num_catego else print('correcto')
# Out:
# correcto

# %%
#contamos el numero de productos vendidos por categoria.
df_categoria_producto=df_limpio.groupby("categoria")['id_venta'].count().reset_index()
df_categoria_producto
# Out:
#            categoria  id_venta
# 0              Books     14950
# 1           Clothing     17593
# 2        Electronics     15616
# 3     Home & Kitchen     14786
# 4  Sports & Outdoors     16975

# %%
df_categoria_producto['Total_vendidos']=df_limpio.groupby("cantidad")['categoria'].sum()
df_categoria_producto
# Out:
#            categoria  id_venta  \
# 0              Books     14950
# 1           Clothing     17593
# 2        Electronics     15616
# 3     Home & Kitchen     14786
# 4  Sports & Outdoors     16975
#
#                                       Total_vendidos
# 0                                                NaN
# 1  Sports & OutdoorsBooksBooksBooksHome & Kitchen...
# 2  ClothingElectronicsSports & OutdoorsHome & Kit...
# 3  Home & KitchenElectronicsSports & OutdoorsBook...
# 4  BooksSports & OutdoorsSports & OutdoorsElectro...

# %%
plt.pie("categoria", labels=)
